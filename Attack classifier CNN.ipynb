# %%
from __future__ import print_function, division
from builtins import range

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers import Dense, Input, GlobalMaxPool1D
from keras.layers import Conv1D, MaxPooling1D, Embedding
from keras.models import Model
from sklearn.metrics import roc_auc_score

# %%
MAX_SEQUENCE_LENGTH = 200
MAX_VOCAB_SIZE = 20000
EMBEDDING_DIM = 100
VALIDATION_SPLIT = 0.2
BATCH_SIZE = 128
EPOCHS = 100

# %%
# load in pre-tained word vectors
print("Loading word vectors...")
word2vec = {}
with open(os.path.join('data/glove.6B.%sd.txt' % EMBEDDING_DIM)) as f:
    for line in f:
        values = line.split()
        word = values[0]
        vec = np.asarray(values[1:], dtype='float32')
        word2vec[word] = vec
print('Found %s word vectors.' % len(word2vec))

# %%
# prepare the text smaples and their labels
print('Loading in data...')

attack_data = pd.read_csv('data/attackset.csv')
sentences = attack_data['Web Description'].fillna('DUMMY_VALUE').values
possible_labels = ['Bruteforce', 'DoS', 'insider', 'phishing', 'ransomware', 'Trojan', 'Web']
targets = attack_data[possible_labels].values

# %%
# convert the sentences into integers
tokenizer = Tokenizer(num_words=MAX_VOCAB_SIZE)
tokenizer.fit_on_texts(sentences)
sequences = tokenizer.texts_to_sequences(sentences)

# %%
print('max sequence length: ', max(len(s) for s in sentences))
print('min sequence length: ', min(len(s) for s in sentences))
s = sorted(len(s) for s in sequences)
print('median sequence length: ', s[len(s) // 2])
print('max word index: ', max(max(seq) for seq in sequences if len(seq) > 0))

# %%
# get word -> integer mapping
word2idx = tokenizer.word_index
print('Found %s unique tokens.' % len(word2idx))

# %%
# pad sequence so that we get N x T matrix
data = pad_sequences(sequences, maxlen=MAX_SEQUENCE_LENGTH)
print('Shape of data tensor: ', data.shape)

# %%
# prepare embedding matrix
print('Filling pre-trained embeddings...')
num_words = min(MAX_VOCAB_SIZE, len(word2idx) +1)
embedding_matrix = np.zeros((num_words, EMBEDDING_DIM))
for word, i in word2idx.items():
    if i < MAX_VOCAB_SIZE:
        embedding_vector = word2vec.get(word)
        if embedding_vector is not None:
            # words not found in embedding index will be all zeros
            embedding_matrix[i] = embedding_vector

# %%
from sklearn.model_selection import train_test_split    
from sklearn.preprocessing import MinMaxScaler

# %%
X_train, X_test, y_train, y_test = train_test_split(data, targets, test_size=VALIDATION_SPLIT, random_state=101)

# %%
# load pre-trained word embeddings into an Embedding layer
# note that we set trainable = False so as to keep the embeddings fixed
embedding_layer = Embedding(
    num_words,
    EMBEDDING_DIM,
    weights=[embedding_matrix],
    input_length=MAX_SEQUENCE_LENGTH,
    trainable=False
)

# %%
print('Building model...')
input_ = Input(shape=(MAX_SEQUENCE_LENGTH,))
x = embedding_layer(input_)
x = Conv1D(128, 3, activation='relu')(x)
x = MaxPooling1D(3)(x)
x = Conv1D(128, 3, activation='relu')(x)
x = MaxPooling1D(3)(x)
x = Conv1D(128, 3, activation='relu')(x)
x = GlobalMaxPool1D()(x)
x = Dense(128, activation='relu')(x)
output = Dense(len(possible_labels), activation='sigmoid')(x)

# %%
model = Model(input_, output)
model.compile(
    loss='binary_crossentropy',
    optimizer='rmsprop',
    metrics=['accuracy']
)

# %%
print('Training model...')
r = model.fit(
    X_train,y_train,
    batch_size=BATCH_SIZE,
    epochs=EPOCHS,
    validation_data=(X_test, y_test)
)
# Out:
# Training model...
# Epoch 1/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.4377 - accuracy: 0.2500 - val_loss: 0.3033 - val_accuracy: 0.3631
# Epoch 2/100
# 5/5 [==============================] - 1s 103ms/step - loss: 0.3153 - accuracy: 0.3662 - val_loss: 0.2892 - val_accuracy: 0.4076
# Epoch 3/100
# 5/5 [==============================] - 1s 104ms/step - loss: 0.2967 - accuracy: 0.4331 - val_loss: 0.2961 - val_accuracy: 0.3822
# Epoch 4/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.2781 - accuracy: 0.5653 - val_loss: 0.2526 - val_accuracy: 0.6815
# Epoch 5/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.2949 - accuracy: 0.4857 - val_loss: 0.2528 - val_accuracy: 0.4968
# Epoch 6/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.2253 - accuracy: 0.7134 - val_loss: 0.2244 - val_accuracy: 0.5287
# Epoch 7/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.2376 - accuracy: 0.5924 - val_loss: 0.1788 - val_accuracy: 0.7580
# Epoch 8/100
# 5/5 [==============================] - 1s 105ms/step - loss: 0.1732 - accuracy: 0.7707 - val_loss: 0.1758 - val_accuracy: 0.6624
# Epoch 9/100
# 5/5 [==============================] - 1s 113ms/step - loss: 0.2005 - accuracy: 0.6736 - val_loss: 0.1666 - val_accuracy: 0.6943
# Epoch 10/100
# 5/5 [==============================] - 1s 110ms/step - loss: 0.1570 - accuracy: 0.7787 - val_loss: 0.1787 - val_accuracy: 0.5860
# Epoch 11/100
# 5/5 [==============================] - 1s 108ms/step - loss: 0.1659 - accuracy: 0.7213 - val_loss: 0.1407 - val_accuracy: 0.8089
# Epoch 12/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.1606 - accuracy: 0.7325 - val_loss: 0.1626 - val_accuracy: 0.7389
# Epoch 13/100
# 5/5 [==============================] - 1s 115ms/step - loss: 0.1424 - accuracy: 0.8248 - val_loss: 0.1330 - val_accuracy: 0.8280
# Epoch 14/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.1447 - accuracy: 0.7866 - val_loss: 0.1349 - val_accuracy: 0.8217
# Epoch 15/100
# 5/5 [==============================] - 1s 109ms/step - loss: 0.1394 - accuracy: 0.7834 - val_loss: 0.1732 - val_accuracy: 0.7834
# Epoch 16/100
# 5/5 [==============================] - 1s 106ms/step - loss: 0.1287 - accuracy: 0.8280 - val_loss: 0.1785 - val_accuracy: 0.6306
# Epoch 17/100
# 5/5 [==============================] - 1s 140ms/step - loss: 0.1211 - accuracy: 0.8232 - val_loss: 0.1220 - val_accuracy: 0.8535
# Epoch 18/100
# 5/5 [==============================] - 1s 127ms/step - loss: 0.1282 - accuracy: 0.7882 - val_loss: 0.1248 - val_accuracy: 0.8471
# Epoch 19/100
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0936 - accuracy: 0.9076 - val_loss: 0.1256 - val_accuracy: 0.8280
# Epoch 20/100
# 5/5 [==============================] - 1s 126ms/step - loss: 0.1053 - accuracy: 0.8599 - val_loss: 0.1392 - val_accuracy: 0.7580
# Epoch 21/100
# 5/5 [==============================] - 1s 173ms/step - loss: 0.1152 - accuracy: 0.8217 - val_loss: 0.1117 - val_accuracy: 0.8599
# Epoch 22/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0751 - accuracy: 0.9204 - val_loss: 0.1881 - val_accuracy: 0.6497
# Epoch 23/100
# 5/5 [==============================] - 1s 167ms/step - loss: 0.1219 - accuracy: 0.8232 - val_loss: 0.1100 - val_accuracy: 0.8344
# Epoch 24/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0647 - accuracy: 0.9283 - val_loss: 0.1369 - val_accuracy: 0.8089
# Epoch 25/100
# 5/5 [==============================] - 1s 124ms/step - loss: 0.0640 - accuracy: 0.9124 - val_loss: 0.1546 - val_accuracy: 0.7389
# Epoch 26/100
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0933 - accuracy: 0.8535 - val_loss: 0.1033 - val_accuracy: 0.8535
# Epoch 27/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0535 - accuracy: 0.9538 - val_loss: 0.1015 - val_accuracy: 0.8662
# Epoch 28/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0585 - accuracy: 0.9220 - val_loss: 0.1985 - val_accuracy: 0.7707
# Epoch 29/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0705 - accuracy: 0.9140 - val_loss: 0.0983 - val_accuracy: 0.8662
# Epoch 30/100
# 5/5 [==============================] - 1s 175ms/step - loss: 0.0335 - accuracy: 0.9713 - val_loss: 0.1383 - val_accuracy: 0.7452
# Epoch 31/100
# 5/5 [==============================] - 1s 171ms/step - loss: 0.0505 - accuracy: 0.9411 - val_loss: 0.1170 - val_accuracy: 0.8535
# Epoch 32/100
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0400 - accuracy: 0.9602 - val_loss: 0.0994 - val_accuracy: 0.8854
# Epoch 33/100
# 5/5 [==============================] - 1s 204ms/step - loss: 0.0249 - accuracy: 0.9889 - val_loss: 0.2049 - val_accuracy: 0.6943
# Epoch 34/100
# 5/5 [==============================] - 1s 154ms/step - loss: 0.0722 - accuracy: 0.9220 - val_loss: 0.0949 - val_accuracy: 0.8662
# Epoch 35/100
# 5/5 [==============================] - 1s 156ms/step - loss: 0.0190 - accuracy: 0.9936 - val_loss: 0.0984 - val_accuracy: 0.8854
# Epoch 36/100
# 5/5 [==============================] - 1s 195ms/step - loss: 0.0161 - accuracy: 0.9920 - val_loss: 0.1067 - val_accuracy: 0.8726
# Epoch 37/100
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0421 - accuracy: 0.9538 - val_loss: 0.2858 - val_accuracy: 0.7389
# Epoch 38/100
# 5/5 [==============================] - 1s 145ms/step - loss: 0.0601 - accuracy: 0.9299 - val_loss: 0.0958 - val_accuracy: 0.8726
# Epoch 39/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0125 - accuracy: 0.9984 - val_loss: 0.0980 - val_accuracy: 0.8790
# Epoch 40/100
# 5/5 [==============================] - 1s 158ms/step - loss: 0.0095 - accuracy: 0.9984 - val_loss: 0.1001 - val_accuracy: 0.8726
# Epoch 41/100
# 5/5 [==============================] - 1s 163ms/step - loss: 0.0078 - accuracy: 0.9984 - val_loss: 0.1019 - val_accuracy: 0.8790
# Epoch 42/100
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0089 - accuracy: 0.9952 - val_loss: 0.1615 - val_accuracy: 0.8280
# Epoch 43/100
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0941 - accuracy: 0.8981 - val_loss: 0.0953 - val_accuracy: 0.8726
# Epoch 44/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0100 - accuracy: 0.9984 - val_loss: 0.0997 - val_accuracy: 0.8726
# Epoch 45/100
# 5/5 [==============================] - 1s 139ms/step - loss: 0.0066 - accuracy: 0.9984 - val_loss: 0.1011 - val_accuracy: 0.8662
# Epoch 46/100
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.1070 - val_accuracy: 0.8854
# Epoch 47/100
# 5/5 [==============================] - 1s 121ms/step - loss: 0.0040 - accuracy: 0.9984 - val_loss: 0.1091 - val_accuracy: 0.8790
# Epoch 48/100
# 5/5 [==============================] - 1s 114ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1125 - val_accuracy: 0.8662
# Epoch 49/100
# 5/5 [==============================] - 1s 112ms/step - loss: 0.0818 - accuracy: 0.8981 - val_loss: 0.1210 - val_accuracy: 0.8790
# Epoch 50/100
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0128 - accuracy: 0.9952 - val_loss: 0.1031 - val_accuracy: 0.8854
# Epoch 51/100
# 5/5 [==============================] - 1s 135ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1065 - val_accuracy: 0.8854
# Epoch 52/100
# 5/5 [==============================] - 1s 128ms/step - loss: 0.0036 - accuracy: 1.0000 - val_loss: 0.1109 - val_accuracy: 0.8981
# Epoch 53/100
# 5/5 [==============================] - 1s 129ms/step - loss: 0.0027 - accuracy: 1.0000 - val_loss: 0.1117 - val_accuracy: 0.8790
# Epoch 54/100
# 5/5 [==============================] - 1s 115ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.8790
# Epoch 55/100
# 5/5 [==============================] - 1s 116ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.1192 - val_accuracy: 0.8917
# Epoch 56/100
# 5/5 [==============================] - 1s 123ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1242 - val_accuracy: 0.8917
# Epoch 57/100
# 5/5 [==============================] - 1s 166ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1291 - val_accuracy: 0.8917
# Epoch 58/100
# 5/5 [==============================] - 1s 153ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1252 - val_accuracy: 0.8726
# Epoch 59/100
# 5/5 [==============================] - 1s 176ms/step - loss: 0.1321 - accuracy: 0.9124 - val_loss: 0.1042 - val_accuracy: 0.8917
# Epoch 60/100
# 5/5 [==============================] - 1s 151ms/step - loss: 0.0071 - accuracy: 1.0000 - val_loss: 0.1035 - val_accuracy: 0.8790
# Epoch 61/100
# 5/5 [==============================] - 1s 234ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.1089 - val_accuracy: 0.8790
# Epoch 62/100
# 5/5 [==============================] - 1s 205ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.1140 - val_accuracy: 0.8790
# Epoch 63/100
# 5/5 [==============================] - 1s 138ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.8790
# Epoch 64/100
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.1219 - val_accuracy: 0.8790
# Epoch 65/100
# 5/5 [==============================] - 1s 136ms/step - loss: 9.1444e-04 - accuracy: 1.0000 - val_loss: 0.1254 - val_accuracy: 0.8854
# Epoch 66/100
# 5/5 [==============================] - 1s 142ms/step - loss: 7.3162e-04 - accuracy: 1.0000 - val_loss: 0.1287 - val_accuracy: 0.8790
# Epoch 67/100
# 5/5 [==============================] - 1s 176ms/step - loss: 5.9181e-04 - accuracy: 1.0000 - val_loss: 0.1310 - val_accuracy: 0.8790
# Epoch 68/100
# 5/5 [==============================] - 1s 153ms/step - loss: 4.7571e-04 - accuracy: 1.0000 - val_loss: 0.1362 - val_accuracy: 0.8854
# Epoch 69/100
# 5/5 [==============================] - 1s 152ms/step - loss: 4.1247e-04 - accuracy: 1.0000 - val_loss: 0.1369 - val_accuracy: 0.8790
# Epoch 70/100
# 5/5 [==============================] - 1s 143ms/step - loss: 3.3046e-04 - accuracy: 1.0000 - val_loss: 0.1393 - val_accuracy: 0.8854
# Epoch 71/100
# 5/5 [==============================] - 1s 144ms/step - loss: 2.7212e-04 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.8790
# Epoch 72/100
# 5/5 [==============================] - 1s 140ms/step - loss: 2.1378e-04 - accuracy: 1.0000 - val_loss: 0.1459 - val_accuracy: 0.8790
# Epoch 73/100
# 5/5 [==============================] - 1s 155ms/step - loss: 0.1211 - accuracy: 0.9347 - val_loss: 0.1201 - val_accuracy: 0.8917
# Epoch 74/100
# 5/5 [==============================] - 1s 134ms/step - loss: 0.0041 - accuracy: 0.9984 - val_loss: 0.1091 - val_accuracy: 0.8790
# Epoch 75/100
# 5/5 [==============================] - 1s 136ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.1136 - val_accuracy: 0.8790
# Epoch 76/100
# 5/5 [==============================] - 1s 140ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1179 - val_accuracy: 0.8790
# Epoch 77/100
# 5/5 [==============================] - 1s 166ms/step - loss: 8.1368e-04 - accuracy: 1.0000 - val_loss: 0.1217 - val_accuracy: 0.8790
# Epoch 78/100
# 5/5 [==============================] - 1s 165ms/step - loss: 6.2252e-04 - accuracy: 1.0000 - val_loss: 0.1247 - val_accuracy: 0.8854
# Epoch 79/100
# 5/5 [==============================] - 1s 162ms/step - loss: 4.7833e-04 - accuracy: 1.0000 - val_loss: 0.1280 - val_accuracy: 0.8854
# Epoch 80/100
# 5/5 [==============================] - 1s 151ms/step - loss: 3.7628e-04 - accuracy: 1.0000 - val_loss: 0.1318 - val_accuracy: 0.8854
# Epoch 81/100
# 5/5 [==============================] - 1s 150ms/step - loss: 2.9980e-04 - accuracy: 1.0000 - val_loss: 0.1355 - val_accuracy: 0.8854
# Epoch 82/100
# 5/5 [==============================] - 1s 173ms/step - loss: 2.4203e-04 - accuracy: 1.0000 - val_loss: 0.1373 - val_accuracy: 0.8854
# Epoch 83/100
# 5/5 [==============================] - 1s 151ms/step - loss: 1.9654e-04 - accuracy: 1.0000 - val_loss: 0.1424 - val_accuracy: 0.8854
# Epoch 84/100
# 5/5 [==============================] - 1s 166ms/step - loss: 1.6243e-04 - accuracy: 1.0000 - val_loss: 0.1455 - val_accuracy: 0.8854
# Epoch 85/100
# 5/5 [==============================] - 1s 155ms/step - loss: 1.3274e-04 - accuracy: 1.0000 - val_loss: 0.1498 - val_accuracy: 0.8854
# Epoch 86/100
# 5/5 [==============================] - 1s 131ms/step - loss: 1.0732e-04 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.8854
# Epoch 87/100
# 5/5 [==============================] - 1s 150ms/step - loss: 8.8778e-05 - accuracy: 1.0000 - val_loss: 0.1550 - val_accuracy: 0.8854
# Epoch 88/100
# 5/5 [==============================] - 1s 134ms/step - loss: 7.4879e-05 - accuracy: 1.0000 - val_loss: 0.1596 - val_accuracy: 0.8854
# Epoch 89/100
# 5/5 [==============================] - 1s 118ms/step - loss: 5.9875e-05 - accuracy: 1.0000 - val_loss: 0.1649 - val_accuracy: 0.8854
# Epoch 90/100
# 5/5 [==============================] - 1s 147ms/step - loss: 4.8679e-05 - accuracy: 1.0000 - val_loss: 0.1709 - val_accuracy: 0.8854
# Epoch 91/100
# 5/5 [==============================] - 1s 147ms/step - loss: 4.2230e-05 - accuracy: 1.0000 - val_loss: 0.1810 - val_accuracy: 0.8854
# Epoch 92/100
# 5/5 [==============================] - 1s 157ms/step - loss: 0.2086 - accuracy: 0.8726 - val_loss: 0.1203 - val_accuracy: 0.8917
# Epoch 93/100
# 5/5 [==============================] - 1s 164ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.1170 - val_accuracy: 0.8854
# Epoch 94/100
# 5/5 [==============================] - 1s 162ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.1186 - val_accuracy: 0.8917
# Epoch 95/100
# 5/5 [==============================] - 1s 141ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.1216 - val_accuracy: 0.8854
# Epoch 96/100
# 5/5 [==============================] - 1s 157ms/step - loss: 7.9197e-04 - accuracy: 1.0000 - val_loss: 0.1250 - val_accuracy: 0.8854
# Epoch 97/100
# 5/5 [==============================] - 1s 176ms/step - loss: 5.9686e-04 - accuracy: 1.0000 - val_loss: 0.1282 - val_accuracy: 0.8854
# Epoch 98/100
# 5/5 [==============================] - 1s 165ms/step - loss: 4.5969e-04 - accuracy: 1.0000 - val_loss: 0.1312 - val_accuracy: 0.8854
# Epoch 99/100
# 5/5 [==============================] - 1s 147ms/step - loss: 3.5418e-04 - accuracy: 1.0000 - val_loss: 0.1343 - val_accuracy: 0.8854
# Epoch 100/100
# 5/5 [==============================] - 1s 138ms/step - loss: 2.7693e-04 - accuracy: 1.0000 - val_loss: 0.1365 - val_accuracy: 0.8917

# %%
plt.plot(r.history['loss'], label='loss')
plt.plot(r.history['val_loss'], label='val_loss')
plt.legend()
plt.show()

# %%
plt.plot(r.history['accuracy'], label='acc')
plt.plot(r.history['val_accuracy'], label='val_acc')
plt.legend()
plt.show()

# %%
p = model.predict(data)
aucs = []
for j in range(6):
    auc = roc_auc_score(targets[:,j], p[:,j])
    aucs.append(auc)
print(np.mean(aucs))
# Out:
# 0.9939343136893696

# %%
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.preprocessing import MultiLabelBinarizer

# %%
probability = model.predict(X_test)

# %%
thresh = 0.5
predictions = np.array([[1 if i > thresh else 0 for i in j] for j in probability])

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       0.00      0.00      0.00         2
#            3       1.00      1.00      1.00        53
#            4       1.00      0.76      0.86        41
#            5       0.00      0.00      0.00         4
#            6       0.79      0.86      0.82        57
#
#    micro avg       0.91      0.85      0.88       157
#    macro avg       0.40      0.37      0.38       157
# weighted avg       0.89      0.85      0.86       157
#  samples avg       0.84      0.85      0.85       157
